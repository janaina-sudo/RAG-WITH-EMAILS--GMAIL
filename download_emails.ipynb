# %%
import os 
import pickle
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from base64 import urlsafe_b64decode, urlsafe_b64encode
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.image import MIMEImage
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from mimetypes import guess_type as guess_mime_type

# %%
class EmailDownloader:
        
        '''
            This class is responsible for downloading emails from a gmail account.
            
            Attributes:
                scopes (list): The scope of the gmail account.
                our_gmail (str): The gmail account to be accessed.
        '''

        def __init__(self, scopes, our_gmail):

            '''
                The constructor for EmailDownloader class.
            '''
            self.scopes = scopes
            self.our_gmail = our_gmail


        
        def gmail_authenticate(self):

            '''
                This function is responsible for authenticating the gmail account.
                It checks if the token.pickle file exists, if it does not exist, it creates it.
                It returns the service object.
            
                Returns:
                    build: The service object.
            '''
            creds = None

            if os.path.exists('token.pickle'):
                with open('token.pickle', 'rb') as token:
                    creds = pickle.load(token)

            if not creds or not creds.valid:

                if creds and creds.expired and creds.refresh_token:
                    creds.refresh(Request())
                
                else: 
                    flow = InstalledAppFlow.from_client_secrets_file('credentials.json', scopes=self.scopes)
                    creds = flow.run_local_server(port=0)
                
                with open("token.pickle", "wb") as token:
                    pickle.dump(creds, token)
            return build('gmail', 'v1', credentials=creds)


        def search_messages(self, service, query, max_results):

            '''
                This function is responsible for searching messages in the gmail account.
                It returns list of messages found.

                Args:
                    service (build): The service object.
                    query (str): The query to be searched.
                    max_results (int): The maximum number of results to return.

                Returns:
                    list: The list of messages found.
            '''

            result = service.users().messages().list(userId='me', q=query, maxResults=max_results).execute()
            messages = []

            if 'messages' in result:
                messages.extend(result['messages'])

            while 'nextPageToken' in result and len(messages) < max_results:
                page_token = result['nextPageToken']
                remaining_results = max_results - len(messages)
                result = service.users().messages().list(userId='me', q=query, pageToken=page_token, maxResults=remaining_results).execute()
                if 'messages' in result:
                    messages.extend(result['messages'])

            return messages[:max_results]


        def clean(self, subject):

            '''
                This function is responsible for creating a folder 
                name that does not contain spaces and special characters.

                Args:
                    subject (str): The subject of the email.
                
                returns:
                    str: The cleaned subject.
            '''
            return "".join(c if c.isalnum() else "_" for c in subject)

        def get_size_format(self, size, factor=1024, suffix="B"):

            '''
                This function is responsible for getting the size format scale bytes
                to its proper byte format. It returns the size format.

                Args:
                    size (int): The size of the email.
                    factor (int): The factor of the email.
                    suffix (str): The suffix of the email.
                
                Returns:
                    str: The size format of the email.
            '''

            for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
                if size < factor:
                    return f"{size:.2f}{unit}{suffix}"
                size /= factor
            return f"{size:.2f}Y{suffix}"

        def save_email_as_eml(self, service, message, folder_name, file_name):
                
            '''
                    This function is responsible for saving the email as an .eml file.
                    It returns the email as an .eml file.
    
                    Args:
                        service (build): The service object.
                        message (dict): The message to be saved.
                        folder_name (str): The folder name of the email.
                        file_name (str): The file name of the email.
            '''

            raw_msg = service.users().messages().get(userId='me', id=message['id'], format='raw').execute()
            eml_data = urlsafe_b64decode(raw_msg['raw'].encode('ASCII'))
            with open(os.path.join(folder_name, file_name), 'wb') as eml_file:
                eml_file.write(eml_data)

        def parse_parts(self, service, parts, folder_name, message):
                
            '''
                   This function analyzes the parts of the email and saves the message .html and attachment.
    
                    Args:
                        service (build): The service object.
                        parts (list): The list of parts of the email.
                        folder_name (str): The folder name of the email.
                        message (dict): The message to be parsed.
            '''
            if parts:
                for part in parts:
                    filename = part.get("filename")
                    mimeType = part.get("mimeType")
                    body = part.get("body")
                    data = body.get("data")
                    file_size = body.get("size")
                    part_headers = part.get("headers")

                    if part.get("parts"):
                        self.parse_parts(service, part.get("parts"), folder_name, message)

                    if mimeType == "text/plain":
                        if data:
                            text = urlsafe_b64decode(data).decode()
                            print(text)

                    elif mimeType == "text/html":
                        if not filename:
                            filename = "index.html"
                        filepath = os.path.join(folder_name, filename)
                        print("Saving HTML to", filepath)
                        with open(filepath, "wb") as f:
                            f.write(urlsafe_b64decode(data))
                    
                    else:
                        for part_header in part_headers:
                            part_header_name = part_header.get("name")
                            part_header_value = part_header.get("value")

                            if part_header_name == "Content-Disposition":
                                if "attachment" in part_header_value:
                                    print("Saving the file:", filename, "size:", self.get_size_format(file_size))
                                    attachment_id = body.get("attachmentId")
                                    attachment = service.users().messages().attachments().get(
                                        id=attachment_id, userId='me', messageId=message['id']).execute()
                                    data = attachment.get("data")
                                    filepath = os.path.join(folder_name, filename)
                                    if data:
                                        with open(filepath, "wb") as f:
                                            f.write(urlsafe_b64decode(data))

        def read_message(self, service, message, base_folder="emails"):

            '''
                This function is responsible for reading the message and saving using save_email_as_eml function.

                Args:
                    service (build): The service object.
                    message (dict): The message to be read.
                    base_folder (str): The base folder of the email.
            '''
            msg = service.users().messages().get(userId='me', id=message['id'], format='full').execute()
            payload = msg['payload']
            headers = payload.get("headers")
            parts = payload.get("parts")
            folder_name = base_folder
            has_subject = False

            if headers:
                for header in headers:
                    name = header.get("name")
                    value = header.get("value")
                    if name.lower() == 'from':
                        print("From:", value)
                    if name.lower() == "to":
                        print("To:", value)
                    if name.lower() == "subject":
                        has_subject = True
                        folder_name = os.path.join(base_folder, self.clean(value))
                        os.makedirs(folder_name, exist_ok=True)
                        print("Subject:", value)
                    if name.lower() == "date":
                        print("Date:", value)
            
            if not has_subject:
                folder_name = os.path.join(base_folder, "no_subject")
                os.makedirs(folder_name, exist_ok=True)
  
            self.parse_parts(service, parts, folder_name, message)
            self.save_email_as_eml(service, message, folder_name, f"{message['id']}.eml")

            print("="*50)

# %%
if __name__ == "__main__":

    ''' Define the scopes and the gmail account.'''
    SCOPES = ['https://mail.google.com/']
    our_gmail = os.environ.get('GMAIL')

    ''' Create an instance of EmailDownloader class.'''
    email_download = EmailDownloader(SCOPES, our_gmail)
    auth = email_download.gmail_authenticate()
    
    ''' Search for messages from user and get the messages.'''
    message_list = auth.users().messages().list(userId='me', q='in: inbox', maxResults=300).execute()
    messages = message_list.get('messages', [])

    ''' Create a folder to save the emails if not exists.'''
    base_folder = "emails"
    if not os.path.exists(base_folder):
        os.makedirs(base_folder)

    ''' Read the messages and save them.'''
    for message in messages:
        email_download.read_message(auth, message, base_folder)


    # References: https://thepythoncode.com/article/use-gmail-api-in-python
# Out:
# From: "Comunicação UECE" <assecom@uece.br>
# Date: Tue, 18 Jun 2024 17:04:42 -0300
# Subject: [Geral-Alunos] [NOTÍCIA] Descarbonização na Uece: chegou a hora de encarar o desafio
# To: undisclosed-recipients:;
# [image: DestaqueDescarbonizaUece.png]
#
# O cenário climático mundial enfrenta desafios significativos devido ao
# aumento das emissões de gases de efeito estufa, causando aquecimento
# global, eventos climáticos extremos mais frequentes e muitos outros
# impactos. Há uma urgência crescente por ações globais coordenadas para
# reduzir as emissões, adotar energias renováveis e promover a educação
# climática, visando garantir um futuro mais sustentável.
#
# A Universidade Estadual do Ceará (Uece), consciente dessa realidade e de
# seu papel na sociedade, dará início ao processo para planejar a adequação
# de suas políticas, práticas, infraestrutura e logística à necessária
# redução de suas próprias emissões, tendo como base a campanha já aderida
# pela instituição, “Race to Zero”, apoiada pela Organização das Nações
# Unidas (ONU).
#
# Para isso, a Uece realizará um conjunto de ações coletivas, de modo que,
# juntos, professores, estudantes e servidores, de todas as unidades
# acadêmicas, construam um Plano de Descarbonização da Uece. Os fóruns terão
# início no próximo dia 25 de junho, a partir das 14h, no campus Itaperi; no
# dia 26, no turno da manhã, no auditório do Centro de Humanidades; e no dia
# 27, também no turno da manhã, em Quixadá.
#
# Em breve será divulgado um cronograma completo de fóruns e, desde já, a
# Universidade Estadual do Ceará chama sua comunidade para participar dessa
# necessária iniciativa coletiva.
#
#
#
# --
# Assessoria de Comunicação UECE
# Avenida Silas Munguba, 1700 - Campus Itaperi
#
#
# Acompanhe nossas redes sociais:
# Instagram: @ueceoficial <https://www.instagram.com/ueceoficial/>
# Facebook: Uece Oficial <https://www.facebook.com/UeceOficial>
# Youtube: Uece Oficial <https://www.youtube.com/UeceOficial>
# Site: www.uece.br
#
# Saving HTML to emails/_Geral_Alunos___NOTÍCIA__Descarbonização_na_Uece__chegou_a_hora_de_encarar_o_desafio/index.html
# ==================================================
# From: The Miro Team <no-reply@e.miro.com>
# To: <janaina.ribeiro@aluno.uece.br>
# Subject: We’re introducing new terms on the use of Miro AI features
# Date: Tue, 18 Jun 2024 13:54:55 -0600
# Learn more about changes we're introducing on July 17, 2024.
#
# ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏
# ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌
# ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏
# ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌
# ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏
# ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌
# ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏ ‌ ͏
# ‌ ͏ ‌
# [
#  [Miro]
# ](https://miro.com/app/dashboard?link=logo-header)
#
# We’re introducing new terms on the use of Miro AI features
# On July 17, 2024, we’re introducing a new [AI Features Addendum](https://miro.com/legal/ai-features-addendum/) that will supplement the agreement you have with Miro. We’re also updating the [Miro Privacy Policy](https://miro.com/legal/privacy-policy-july-17/). These changes make it easier for you to understand what to expect from Miro as you use our AI features, such as Miro Assist.
# You can review the new terms [here](https://miro.com/legal/ai-features-addendum/). At a glance, these updates explain:
# •
#
# How Miro uses inputs you provide and output generated by Miro AI
# features.
# •
#
# Ownership of output generated by Miro’s AI features.
# •
#
# Limitations associated with the quickly-evolving technologies
# that underpin Miro AI features.
# You don't have to do anything to accept these changes. By
# continuing to use Miro after July 17th you are agreeing to the
# new terms. If you have questions check the FAQ below.
# AI Features Addendum FAQ
# We don’t train generative AI with your board content. Miro relies
# on commercially available models (such as developed by OpenAI) as
# well as open-source models that are trained with licensed data
# and public domain content where copyright has expired. Miro may
# use usage data and other meta data to improve your product
# experience and develop features like diagramming and sticky
# clustering.
# You can choose not to participate in our AI feature improvement
# efforts. We currently don’t use your input into and output from
# Miro AI features to improve our product. If we intend to change
# our training approach, we will inform you upfront.
# You own your board content. No license granted to Miro to operate
# its services will supersede your ownership rights.
# Thank you for using Miro!
# The Miro Team
#
#
#
# You have received this mandatory email service announcement to
# update you about important changes in connection with Miro’s
# Terms of Service. You are a subject to Miro's Terms of Service
# because you have an account with Miro.
#
# Please do not reply to this email, as we are unable to respond from this email address. If you need support, please visit [Miro’s Help Center](https://help.miro.com/hc/en-us).
#
# This email was sent to [janaina.ribeiro@aluno.uece.br](mailto:https://click.e.miro.com/?qs=ea46aedc7b75fffc91c0e17f72a2436e5871710e45cbfe1a116b3017a552ec77a874a31c1f8a8396da26260fd1b04073e024ef20bda4009551ac06562daef835).
#
# [
#  [Miro]
# ](https://miro.com/app/dashboard?link=logo-footer)
#
# Miro, 201 Spear St., Suite 1100
# San Francisco, CA 94105, United States
#
# [Help Center](https://help.miro.com/hc/) | [Privacy Policy](https://miro.com/legal/privacy-policy/)
#
# Saving HTML to emails/We_re_introducing_new_terms_on_the_use_of_Miro_AI_features/index.html
# ==================================================
# Date: Tue, 18 Jun 2024 16:44:18 -0300
# Subject: [últimas horas] Cursos Exclusivos + Discord + Monitoria na Condição especial Estudonauta
# From: Professor Gustavo Guanabara <info@cursoemvideo.com>
# To: "Janaína Ribeiro" <janaina.ribeiro@aluno.uece.br>
# OLÁ PEQUENO GAFANHOTO!
#
# Seu cupom de desconto: BLACK2022
# 50% para adesão ao Estudonauta pelos 3 primeiros meses de adesão ou
# para o plano anual *
#
# O Curso em Vídeo já é o maior projeto educacional do Brasil
# totalmente gratuito. Onde disponibilizamos centenas de aulas grátis
# para você estudar online.
#
# Mas a gente sabe que estudar sem apoio não é fácil. Por isso
# convidamos você para se matricular no Estudonauta, onde você conta
# com Cursos exclusivos, Fórum de Tutoria e um servidor exclusivo no
# Discord para melhorar a sua experiência de ensino. O objetivo da
# tutoria é te ajudar a alcançar o sucesso nos estudos através de um
# acompanhamento sistemático.
#
# No Estudonauta você pode tirar certificados sem limites e conta com
# tutoria através do Fórum exclusivo para assinantes.
#
# Veja alguns cursos exclusivos para alunos do Estudonauta
#
# * Programação Básica
# * PHP com Mysql
# * Android Studio
# * Linguagem C
# * Linguagem C#
# * Linguagem Kotlin
# * Segurança da Informação
# * Arquitetura de Computadores
# * Eletrônica Básica
#
# * Produção de Conteúdo Youtube
#
# Assine o Estudonauta com desconto especial
#
# Existem vagas abertas. Mas corre! Porque elas são limitadas!
#
# >> Assista este vídeo que eu vou te explicar tim-tim por tim-tim!
#
# Atenciosamente,
#
# Professor Gustavo Guanabara
#
# <a href="https://info.cursoemvideo.com/email/unsubscribe/6671e3951e3cc558807230">Cancelar Inscrição</a> para não receber mais nossos emails.
# Saving HTML to emails/_últimas_horas__Cursos_Exclusivos___Discord___Monitoria_na_Condição_especial_Estudonauta/index.html
# ==================================================
# From: "Ka Solution | Treinamentos Oficiais" <cursos@kasolution.com.br>
# To: <janaina.ribeiro@aluno.uece.br>
# Subject: AWS Discovery Day - É nesse sábado!
# Date: Tue, 18 Jun 2024 14:08:56 -0300
# Caso você não visualize esse e-mail, clique aqui.
# <https://www.kasolution.com.br/hotmail/20240617-aws-evento.html>
#
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/Home?pt=mail>  	+55 (11) 5091-1616 | +55
# (21) 3848-9600 	Siga-nos nas redes sociais 	Visite nosso site:
# www.kasolution.com.br
# <https://www.kasolution.com.br/social/whatsapp.html>  	Visite nosso
# site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/Linkedin.html>  	Visite nosso
# site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/Instagram.html>  	Visite nosso
# site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/Youtube.html>  	Visite nosso
# site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/Facebook.html>  	Visite nosso
# site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/Twitter.html>
#
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/CursoGratisAWS.html?pt=mail>
#
# 	 Visite nosso site:
# www.kasolution.com.br<https://www.kasolution.com.br/hotmail/imagens/2023
# 1123/calendar.PNG> 	neste sábado dia 22/06 das 09h às 13h
#
# AWS Discovery Day - Cloud Practitioner Essentials
# Curso ideal para quem quer aprender mais sobre Cloud Computing
#
# CLIQUE AQUI E INSCREVA-SE JÁ!
# <https://www.kasolution.com.br/social/CursoGratisAWS.html?pt=mail>
#
#
# O treinamento será realizado gratuitamente e 100% a distância.
#
# Caso você queira dar o primeiro passo em seu aprendizado sobre Nuvem
# AWS, aproveite essa super chance. Este curso é projetado para apresentar
# os serviços básicos de infraestrutura da AWS. O conteúdo do evento é
# introdutório e tem como objetivo ajudar o aluno a entender o benefícios
# da computação em nuvem.
#
# Após concluir este treinamento, os alunos serão capazes de entender o
# que é a nuvem e como ela funciona, os benefícios da Nuvem AWS, os
# principais serviços da AWS e seus casos de uso comuns (computação,
# armazenamento, banco de dados, etc.), a infraestrutura global básica da
# nuvem, características básicas de implantação e operação na Nuvem AWS, o
# modelo de responsabilidade compartilhada e aspectos básicos de segurança
# e conformidade da plataforma AWS.
#
# Por que participar?
#
#
#  Icon
# 1<https://www.kasolution.com.br/hotmail/imagens/20240429/teacher.png>
#
# 2 instrutores AWS
#
# 	 Icon
# 2<https://www.kasolution.com.br/hotmail/imagens/20240429/video.png>
#
# Possibilidade de rever
#
# 	 Icon
# 3<https://www.kasolution.com.br/hotmail/imagens/20240429/clipboard.png>
#
# Enquetes ao vivo
#
# 	 Icon
# 4<https://www.kasolution.com.br/hotmail/imagens/20240429/open-book.png>
#
# Material oficial
#
#  Icon
# 1<https://www.kasolution.com.br/hotmail/imagens/20240429/award.png>
#
# Preparatório para iniciar no mercado
#
# 	 Icon
# 2<https://www.kasolution.com.br/hotmail/imagens/20240429/certificate.png
# >
#
# Certificado de participação
#
# 	 Icon
# 3<https://www.kasolution.com.br/hotmail/imagens/20240429/gift.png>
#
# Sorteio de vouchers de exame
#
# 	 Icon
# 4<https://www.kasolution.com.br/hotmail/imagens/20240429/hello.png>
#
# Acessibilidade em libras
#
#
# Confira depoimentos de alunos KApacitados:
#
#
#  Visite nosso site:
# www.kasolution.com.br<https://www.kasolution.com.br/hotmail/imagens/2024
# 0617/depoimentos.jpg> 	"O curso foi maravilhoso, muito didático,
# instrutores super alto astral, pacientes e carismáticos, ajudou muito
# pra quem está querendo saber e se aprimorar em aws. sugestão na próxima
# falar sobre VPN."
# Fernanda Santana
#
# "Em breve pretendo tirar a certificação, e curso me ajudou bastante,
# fora a ideia de criação de uma mapa mental que me já fez ter várias
# ideias para fixar conhecimento de maneira mais prática."
# Miguel Vale
#
# "Gostei muito. No início eu pensei que seria um treinamento muito
# básico, mas falou de coisas que eu ainda não conhecia bem. Enriqueceu
# demais meu conhecimento."
# Essias Souza
#
# + 304 mil alunos já KApacitados gratuitamente!
#
# Últimas vagas!
# CLIQUE AQUI E INSCREVA-SE JÁ!
# <https://www.kasolution.com.br/social/CursoGratisAWS.html?pt=mail>
#
#
# Outros cursos e certificações oficiais AWS:
#
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98000/Curso/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98002/Curso/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98015/Curso/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98010/Curso/A/S?pt=mail>
#
# Practitioner <https://www.kasolution.com.br/AWS/98000/Curso/A/S?pt=mail>
# Solutions Architect
# <https://www.kasolution.com.br/AWS/98002/Curso/A/S?pt=mail>
# SysOps <https://www.kasolution.com.br/AWS/98015/Curso/A/S?pt=mail>
# Developer <https://www.kasolution.com.br/AWS/98010/Curso/A/S?pt=mail>
#
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98020/Curso/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/ACDAS/Cursos/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98025/Curso/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/ACMLS/Cursos/A/S?pt=mail>
#
# Adv. Networking
# <https://www.kasolution.com.br/AWS/98020/Curso/A/S?pt=mail>
# Data Analytics
# <https://www.kasolution.com.br/AWS/ACDAS/Cursos/A/S?pt=mail>
# Database <https://www.kasolution.com.br/AWS/98025/Curso/A/S?pt=mail>
# Machine Learning
# <https://www.kasolution.com.br/AWS/ACMLS/Cursos/A/S?pt=mail>
#
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98023/Curso/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS?pt=mail>  		Visite nosso
# site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/ACDOEP/Cursos/A/S?pt=mail>
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/AWS/98005/Curso/A/S?pt=mail>
#
# Security <https://www.kasolution.com.br/AWS/98023/Curso/A/S?pt=mail>
# SAP on AWS <https://www.kasolution.com.br/AWS?pt=mail>
# DevOps Engineer
# <https://www.kasolution.com.br/AWS/ACDOEP/Cursos/A/S?pt=mail>
# Sol. Architect Pro
# <https://www.kasolution.com.br/AWS/98005/Curso/A/S?pt=mail>
#
# Visite nosso site: www.kasolution.com.br
# <https://www.kasolution.com.br/social/whatsapp.html?pt=mail>
#
#  Visite nosso site:
# www.kasolution.com.br<https://www.kasolution.com.br/hotmail/imagens/2023
# 1123/RODAPE.PNG>
#
#  <https://www.kasolution.com.br/sap?pt=mail>
# <https://www.kasolution.com.br/microsoft?pt=mail>
# <https://www.kasolution.com.br/AWS?pt=mail>
# <https://www.kasolution.com.br/Gestao/1016/Curso/G/S?pt=mail>
# <https://www.kasolution.com.br/redhat?pt=mail>
# <https://www.kasolution.com.br/citrix?pt=mail>
# <https://www.kasolution.com.br/vmware?pt=mail>
# <https://www.kasolution.com.br/Microsoft/Paginas/Exames?pt=mail>
# <https://www.kasolution.com.br/isc?pt=mail>
# <https://www.kasolution.com.br/dynatrace?pt=mail>
# <https://www.kasolution.com.br/Gestao/1210/Curso/G/S?pt=mail>
#
# Forma de pagamento <https://www.kasolution.com.br/home?pt=mail>
# Ka Solution
# Maior Centro Educacional Oficial Microsoft da América Latina
# Maior Centro de Formação de Consultores SAP na América Latina
# Centro Educacional Oficial AWS, Oracle Workforce Development
# Centro Educacional Oficial Citrix, VMware, SAS, (ISC)2, Dynatrace,
# Mastersaf e DELLEMC
# Eleita como a melhor empresa integradora de soluções de e-learning
# Melhor Empresa de Treinamento eleita pelo Jornal ComputerWorld
#
# Clique aqui se quiser remover seu e-mail desta lista
# enviado para: janaina.ribeiro@aluno.uece.br
# <https://www.kasolution.com.br/sair?pt=Mail>
#
#
#
# Saving HTML to emails/AWS_Discovery_Day___É_nesse_sábado_/index.html
# ==================================================
# From: Jose Everardo Bessa Maia <jose.maia@uece.br>
# Date: Tue, 18 Jun 2024 12:26:41 -0300
# Subject: [COMP-L] Fwd: EDITAL SELEÇÃO ESTAGIARIOS FUNCAP
# To: comp-l@aluno.uece.br
# ---------- Forwarded message ---------
# De: adriele santos <adriele.santos@funcap.ce.gov.br>
# Date: ter., 18 de jun. de 2024 às 09:43
# Subject: EDITAL SELEÇÃO ESTAGIARIOS FUNCAP
# To: coordadm@uece.br <coordadm@uece.br>, thiciane.teixeira@uece.br <
# thiciane.teixeira@uece.br>, cccomp@uece.br <cccomp@uece.br>,
# jose.maia@uece.br <jose.maia@uece.br>, fisica.cct@uece.br <
# fisica.cct@uece.br>, sergio.sombra@uece.br <sergio.sombra@uece.br>
#
#
# Prezados,
# Bom dia.
#
# Queria compartilhar que a FUNCAP está  com edital aberto para seleção de
# estagiários de nível superior, se puderem ajudar na divulgação. Segue
# anexo.
#
#
#
# Atenciosamente,
#
#
# Saving HTML to emails/_COMP_L__Fwd__EDITAL_SELEÇÃO_ESTAGIARIOS_FUNCAP/index.html
# Saving the file: SELEÇÃO ESTAGIO NIVEL  SUPERIOR FUNCAP.pdf size: 231.64KB
# ==================================================
# Subject: Your AI Engineer Toolkit is Now an E-Book!
# From: "Louis-François from Towards AI" <louistowardsai@substack.com>
# To: janaina.ribeiro@aluno.uece.br
# Date: Tue, 18 Jun 2024 14:04:33 +0000
# View this post on the web at https://louistowardsai.substack.com/p/your-ai-engineer-toolkit-is-now-an
#
# Good morning, fellow learners! This is Louis-François [ https://link.sbstck.com/redirect/069d2a18-c8c5-4054-8cc2-d74825ca3346?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ] again from Towards AI, bringing yet another exciting news.
# We’ve heard you. We now know many of you prefer a digital learning experience, and since the launch of our book, Building LLMs for Production [ https://link.sbstck.com/redirect/ea46efca-f786-4303-9bf9-dd42baf13f26?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ], we have been actively working on making it more accessible for all of you. So, after working out the kinks, we are finally excited to release the electronic version of "Building LLMs for Production [ https://link.sbstck.com/redirect/ea46efca-f786-4303-9bf9-dd42baf13f26?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ]."
# Think of this version as your “carry it wherever you go” AI engineer toolkit. Enjoy enhanced accessibility and easy navigation!
# We worked hard to ensure it offered a more interactive experience and knowledge through the embedded links (great free learning references), especially for coding examples. Find it now on Amazon as a paperback, high-quality colored hardcover, and e-book [ https://link.sbstck.com/redirect/ea46efca-f786-4303-9bf9-dd42baf13f26?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ]!
# We have also released a paperback specifically for our community in India. Thanks to a partnership with Shroff Publishers, you can order it here [ https://link.sbstck.com/redirect/0b3413f2-e28f-4726-9422-bd72f2b39642?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ]!
# For those of you that missed our announcement and seeing this book for the first time, Building LLMs for Production [ https://link.sbstck.com/redirect/ea46efca-f786-4303-9bf9-dd42baf13f26?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ] aims to help you develop 1) Prompt Engineering [ https://link.sbstck.com/redirect/243a121d-c930-4529-b412-3b5d2ecd7322?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ], 2) Retrieval Augmented Generation (RAG) [ https://link.sbstck.com/redirect/6c7668ee-ec43-4dd6-8e09-50e1b77208e0?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ], 3) Fine-Tuning [ https://link.sbstck.com/redirect/96bbee69-81b0-4bf2-84f7-f1acb993d6b1?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ], and 4) Custom UI/UX toolkit to build your own LLM applications.
# With this book, we teach what universities don't. It is a product of all the **challenges we face in a production environment. So, the book particularly focuses on practical solutions for tackling each roadblock.
# The book is packed with theories, concepts, projects, applications, and experience that you can confidently put on your CVs. I also hope it proves to be a great motivation for you to finish the book. And if you do, add this straight into your resume with confidence:
# Large Language Models (LLMs) | LangChain | LlamaIndex | Vector databases | RAG | Prompting | Fine-tuning | Agents | Deployment & Deployment Optimizations | Creating chatbots | Chat with PDFs | Summarization | AI Assistants | RLHF
# Get your copy of Building LLMs for Production to advance your learning journey [ https://link.sbstck.com/redirect/ea46efca-f786-4303-9bf9-dd42baf13f26?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ]!
# We promised no fluff, no spam, and we meant it. If you want to continue your learning journey, sign up here to keep receiving the fundamentals for free [ https://link.sbstck.com/redirect/58f0074c-d9e8-41f1-8b57-accc32bbd351?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ]!
# You will receive various methods to adapt "foundation model" LLMs for “advanced accuracy,” reliability, and scalability, emphasizing the necessity of specific methods like Prompt Engineering, RAG, and Fine-Tuning. And, of course, learn about LLMs from the ground up.
# Thank you for taking the time to read this, and please consider getting the book for yourself or your friends. We are excited to release this product and poured our hearts into it.
# — Louis-François Bouchard [ https://link.sbstck.com/redirect/069d2a18-c8c5-4054-8cc2-d74825ca3346?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ], CTO and Co-Founder at Towards AI [ https://link.sbstck.com/redirect/b479e54c-1733-4501-a58d-ac42e0ef57e9?j=eyJ1IjoiM3o0Nm8xIn0.wRtctR5UN50pG0jmit97_BM0pNHJyOggRgpjkJlp-ZE ]
# P.S. We will only announce here very rarely when we have new advanced LLM courses or products we think are super relevant to you, but please unsubscribe if you don’t wish to hear about them!
#
# Unsubscribe https://substack.com/redirect/2/eyJlIjoiaHR0cHM6Ly9sb3Vpc3Rvd2FyZHNhaS5zdWJzdGFjay5jb20vYWN0aW9uL2Rpc2FibGVfZW1haWw_....5Rbh57TGJeyLV7yDENFPGFq0RLz7sL23UM9C5ZQiJYE?
# Saving HTML to emails/Your_AI_Engineer_Toolkit_is_Now_an_E_Book_/index.html
# ==================================================
# From: "Janaína Santos" <janainaribeiro780@gmail.com>
# Date: Tue, 18 Jun 2024 10:38:48 -0300
# Subject: ...
# To: janaina.ribeiro@aluno.uece.br
# import os
# import pickle
# from base64 import urlsafe_b64decode
# from google.auth.transport.requests import Request
# from google.oauth2.credentials import Credentials
# from google_auth_oauthlib.flow import InstalledAppFlow
# from googleapiclient.discovery import build
#
# class EmailDownloader:
#
#     '''
#         This class is responsible for downloading emails from a gmail
# account.
#
#         Attributes:
#             scopes (list): The scope of the gmail account.
#             our_gmail (str): The gmail account to be accessed.
#     '''
#
#     def __init__(self, scopes, our_gmail):
#
#         '''
#             The constructor for EmailDownloader class.
#         '''
#         self.scopes = scopes
#         self.our_gmail = our_gmail
#
#
#     def gmail_authenticate(self):
#
#         '''
#             This function is responsible for authenticating the gmail
# account.
#             It checks if the token.pickle file exists, if it does not
# exist, it creates it.
#             It returns the service object.
#
#             Returns:
#                 build: The service object.
#         '''
#         creds = None
#
#         if os.path.exists('token.pickle'):
#             with open('token.pickle', 'rb') as token:
#                 creds = pickle.load(token)
#
#         if not creds or not creds.valid:
#
#             if creds and creds.expired and creds.refresh_token:
#                 creds.refresh(Request())
#
#             else:
#                 flow =
# InstalledAppFlow.from_client_secrets_file('credentials.json',
# scopes=self.scopes)
#                 creds = flow.run_local_server(port=0)
#
#             with open("token.pickle", "wb") as token:
#                 pickle.dump(creds, token)
#         return build('gmail', 'v1', credentials=creds)
#
#
#     def search_messages(self, service, query):
#
#         '''
#             This function is responsible for searching messages in the
# gmail account.
#             It returns list of messages found.
#
#             Args:
#                 service (build): The service object.
#                 query (str): The query to be searched.
#
#             Returns:
#                 list: The list of messages found.
#         '''
#
#         result = service.users().messages().list(userId='me',
# q=query).execute()
#         messages = []
#
#         if 'messages' in result:
#             messages.extend(result['messages'])
#
#         while 'nextPageToken' in result:
#             page_token = result['nextPageToken']
#             result = service.users().messages().list(userId='me', q=query,
# pageToken=page_token).execute()
#             if 'messages' in result:
#                 messages.extend(result['messages'])
#
#         return messages
#
#
#     def clean(self, subject):
#
#         '''
#             This function is responsible for creating a folder
#             name that does not contain spaces and special characters.
#
#             Args:
#                 subject (str): The subject of the email.
#
#             returns:
#                 str: The cleaned subject.
#         '''
#         return "".join(c if c.isalnum() else "_" for c in subject)
#
#     def get_size_format(self, size, factor=1024, suffix="B"):
#
#         '''
#             This function is responsible for getting the size format scale
# bytes
#             to its proper byte format. It returns the size format.
#
#             Args:
#                 size (int): The size of the email.
#                 factor (int): The factor of the email.
#                 suffix (str): The suffix of the email.
#
#             Returns:
#                 str: The size format of the email.
#         '''
#
#         for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
#             if size < factor:
#                 return f"{size:.2f}{unit}{suffix}"
#             size /= factor
#         return f"{size:.2f}Y{suffix}"
#
#     def save_email_as_eml(self, service, message, folder_name, file_name):
#
#         '''
#                 This function is responsible for saving the email as an
# .eml file.
#                 It returns the email as an .eml file.
#
#                 Args:
#                     service (build): The service object.
#                     message (dict): The message to be saved.
#                     folder_name (str): The folder name of the email.
#                     file_name (str): The file name of the email.
#         '''
#
#         raw_msg = service.users().messages().get(userId='me',
# id=message['id'], format='raw').execute()
#         eml_data = urlsafe_b64decode(raw_msg['raw'].encode('ASCII'))
#         with open(os.path.join(folder_name, file_name), 'wb') as eml_file:
#             eml_file.write(eml_data)
#
#     def parse_parts(self, service, parts, folder_name, message):
#
#         '''
#                This function analyzes the parts of the email and saves the
# message .html and attachment.
#
#                 Args:
#                     service (build): The service object.
#                     parts (list): The list of parts of the email.
#                     folder_name (str): The folder name of the email.
#                     message (dict): The message to be parsed.
#         '''
#         if parts:
#             for part in parts:
#                 filename = part.get("filename")
#                 mimeType = part.get("mimeType")
#                 body = part.get("body")
#                 data = body.get("data")
#                 file_size = body.get("size")
#                 part_headers = part.get("headers")
#
#                 if part.get("parts"):
#                     self.parse_parts(service, part.get("parts"),
# folder_name, message)
#
#                 if mimeType == "text/plain":
#                     if data:
#                         text = urlsafe_b64decode(data).decode()
#                         print(text)
#
#                 elif mimeType == "text/html":
#                     if not filename:
#                         filename = "index.html"
#                     filepath = os.path.join(folder_name, filename)
#                     print("Saving HTML to", filepath)
#                     with open(filepath, "wb") as f:
#                         f.write(urlsafe_b64decode(data))
#
#                 else:
#                     for part_header in part_headers:
#                         part_header_name = part_header.get("name")
#                         part_header_value = part_header.get("value")
#
#                         if part_header_name == "Content-Disposition":
#                             if "attachment" in part_header_value:
#                                 print("Saving the file:", filename,
# "size:", self.get_size_format(file_size))
#                                 attachment_id = body.get("attachmentId")
#                                 attachment =
# service.users().messages().attachments().get(
#                                     id=attachment_id, userId='me',
# messageId=message['id']).execute()
#                                 data = attachment.get("data")
#                                 filepath = os.path.join(folder_name,
# filename)
#                                 if data:
#                                     with open(filepath, "wb") as f:
#                                         f.write(urlsafe_b64decode(data))
#
#     def read_message(self, service, message, base_folder="emails"):
#
#         '''
#             This function is responsible for reading the message and saving
# using save_email_as_eml function.
#
#             Args:
#                 service (build): The service object.
#                 message (dict): The message to be read.
#                 base_folder (str): The base folder of the email.
#         '''
#         msg = service.users().messages().get(userId='me', id=message['id'],
# format='full').execute()
#         payload = msg['payload']
#         headers = payload.get("headers")
#         parts = payload.get("parts")
#         folder_name = base_folder
#         has_subject = False
#
#         if headers:
#             for header in headers:
#                 name = header.get("name")
#                 value = header.get("value")
#                 if name.lower() == 'from':
#                     print("From:", value)
#                 if name.lower() == "to":
#                     print("To:", value)
#                 if name.lower() == "subject":
#                     has_subject = True
#                     folder_name = os.path.join(base_folder,
# self.clean(value))
#                     os.makedirs(folder_name, exist_ok=True)
#                     print("Subject:", value)
#                 if name.lower() == "date":
#                     print("Date:", value)
#
#         if not has_subject:
#             folder_name = os.path.join(base_folder, "no_subject")
#             os.makedirs(folder_name, exist_ok=True)
#
#         self.save_email_as_eml(service, message, folder_name,
# f"{message['id']}.eml")
#
#         print("="*50)
#
# if __name__ == "__main__":
#     scopes = ["https://www.googleapis.com/auth/gmail.readonly"]
#     our_gmail = "your_email@gmail.com"
#
#     downloader = EmailDownloader(scopes, our_gmail)
#     service = downloader.gmail_authenticate()
#
#     # Modify the query to suit your needs
#     query = "has:attachment"
#     messages = downloader.search_messages(service, query)
#
#     print(f"Found {len(messages)} messages with attachments.")
#
#     for msg in messages:
#         downloader.read_message(service, msg)
#
# Saving HTML to emails/___/index.html
# ==================================================
# From: Matheus Henrique Esteves Paixao <matheus.paixao@uece.br>
# Date: Tue, 18 Jun 2024 09:43:14 -0300
# Subject: [COMP-L] Seminários de Engenharia de Software (19/06)
# To: comp-l <comp-l@aluno.uece.br>, Alunos do PPGCC <ppgcc-uece@googlegroups.com>
# Olá a todos,
#
# Na próxima quarta-feira (19/06), daremos continuidade aos seminários da
# disciplina de Engenharia de Software do PPGCC. Toda a comunidade do BCC e
# do PPGCC é bem vinda para prestigiar as apresentações e contribuir com as
# discussões. Lembrando que os seminários são presenciais.
#
# Segue abaixo os detalhes para o próximo seminário.
#
# *Artigo*: A Literature Review of Using Machine Learning in Software
# Development Life Cycle Stages
# *Data*: 19/06
# *Horário*: 09h20
# *Local*: Mini-auditório do PPGCC
#
# Att,
# Matheus
# --
# Dr. Matheus Paixão
# Engenheiro de Software e Cientista da Computação
# Professor Adjunto da Universidade Estadual do Ceará (UECE)
# Vice Coordenador do Programa de Pós-Graduação em Ciência da Computação
# (PPGCC)
# Doutorado em Ciência da Computação - University College London
# Homepage: mhepaixao.github.io/homepage/
#
#
# Saving HTML to emails/_COMP_L__Seminários_de_Engenharia_de_Software__19_06_/index.html
# ==================================================
# Date: Tue, 18 Jun 2024 12:06:51 +0000
# From: "Amazon.com.br" <store-news@amazon.com.br>
# To: janaina.ribeiro@aluno.uece.br
# Subject: Janaína Santos, ouça milhões de músicas grátis
#
#
#
# Olá Janaína Santos,
# Como cliente Amazon você tem acesso ao Amazon Music, um serviço de streaming de música grátis e sem a necessidade de um cartão de crédito.
# Ouça agora (https://music.amazon.com.br/home)
# Ouça milhões de músicas, milhares de playlists e estações feitas pelos nossos curadores, além de milhões de episódios de podcasts. Saiba mais
#
#
#
# Atualize suas preferências https://www.amazon.com.br/gp/cpc/homepage?ref_=pe_ob_ftr_comm_prfs
# Cancelar assinatura https://www.amazon.com.br/gp/gss/o/1JXZoIQ8yR1mIMWqYCSlPk.jbBVVvOvaNgCmxsBXCceA
# ©2021- 2024 Amazon.com, Inc. ou suas afiliadas Todos os direitos reservados Amazon.com, Amazon.com.br, a logo de Amazon.com são marcas comerciais registradas de Amazon.com, Inc. ou suas afiliadas. Amazon Serviços de Varejo do Brasil Ltda. | CNPJ 15.436.940/0001-03 Av. Juscelino Kubitschek, 2041, Torre E, 18° andar - São Paulo CEP: 04543-011. Ref: 937684170.
#
#
#
# Política de privacidade https://www.amazon.com.br/gp/help/customer/display.html?nodeId=201283950
# Amazon.com.br
# Saving HTML to emails/Janaína_Santos__ouça_milhões_de_músicas_grátis/index.html
# ==================================================
# Date: Mon, 17 Jun 2024 15:46:54 -0300
# Subject: [Seja um Estudonauta] Cursos Exclusivos + Discord + Monitoria na Condição especial Estudonauta
# From: Professor Gustavo Guanabara <info@cursoemvideo.com>
# To: "Janaína Ribeiro" <janaina.ribeiro@aluno.uece.br>
# OLÁ PEQUENO GAFANHOTO!
#
# Seu cupom de desconto: ESTUDO2023
# 50% para adesão ao Estudonauta pelos 3 primeiros meses de adesão ou
# para o plano anual *
#
# Comece o novo ano decidido a evoluir com nosso apoio e cursos
# exclusivos.
# O Curso em Vídeo já é o maior projeto educacional do Brasil
# totalmente gratuito. Onde disponibilizamos centenas de aulas grátis
# para você estudar online.
#
# Mas a gente sabe que estudar sem apoio não é fácil. Por isso
# convidamos você para se matricular no Estudonauta, onde você conta
# com Cursos exclusivos, Fórum de Tutoria e um servidor exclusivo no
# Discord para melhorar a sua experiência de ensino. O objetivo da
# tutoria é te ajudar a alcançar o sucesso nos estudos através de um
# acompanhamento sistemático.
#
# No Estudonauta você pode tirar certificados sem limites e conta com
# tutoria através do Fórum exclusivo para assinantes.
#
# Veja alguns cursos exclusivos para alunos do Estudonauta
#
# * Programação Básica
# * PHP com Mysql
# * Android Studio
# * Linguagem C
# * Linguagem C#
# * Linguagem Kotlin
# * Segurança da Informação
# * Arquitetura de Computadores
# * Eletrônica Básica
#
# * Produção de Conteúdo Youtube
#
# Assine o Estudonauta com desconto especial
#
# Existem vagas abertas. Mas corre! Porque elas são limitadas!
#
# >> Assista este vídeo que eu vou te explicar tim-tim por tim-tim!
#
# [https://www.estudonauta.com/matricula]
#
# Atenciosamente,
#
# Professor Gustavo Guanabara
#
# <a href="https://info.cursoemvideo.com/email/unsubscribe/6670849f9484a701987146">Cancelar Inscrição</a> para não receber mais nossos emails.
# Saving HTML to emails/_Seja_um_Estudonauta__Cursos_Exclusivos___Discord___Monitoria_na_Condição_especial_Estudonauta/index.html
# ==================================================
